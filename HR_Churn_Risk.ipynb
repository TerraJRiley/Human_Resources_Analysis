# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("./data/HR_Cleaned.csv")

# %%
# Exploratory Data Analysis (EDA)
# Correlation Matrix
correlation_matrix = df[['PerfScoreID', 'EmpSatisfaction', 'EngagementSurvey', 'Salary', 
                                 'SpecialProjectsCount', 'Absences', 'DaysLateLast30', 'EmploymentDuration']].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix for Performance, Satisfaction, and Other Metrics')
plt.show()

# %%
# Assigning weights to factors for churn risk
weights = {
    'PerfScoreID': -1,  # Lower performance might indicate higher churn risk
    'EmpSatisfaction': -1,  # Lower satisfaction might indicate higher churn risk
    'EngagementSurvey': -1,  # Lower engagement might indicate higher churn risk
    'Absences': 0.5,  # More absences might indicate higher churn risk
    'DaysLateLast30': 1,  # More days late might indicate higher churn risk
    'EmploymentDuration': -0.1  # Shorter duration might indicate higher churn risk
}

# Normalizing and calculating churn risk score
for factor, weight in weights.items():
    df[factor + '_norm'] = (df[factor] - df[factor].mean()) / df[factor].std()
df['ChurnRiskScore'] = sum([df[factor + '_norm'] * weight for factor in weights])

# %%
# Identifying high-risk individuals
high_risk_threshold = df['ChurnRiskScore'].quantile(0.95)
high_risk_individuals = df[df['ChurnRiskScore'] >= high_risk_threshold]

# %%
# Visualizing Churn Risk Score vs Salary for non-terminated employees
non_terminated_employees = df[df['EmploymentStatus'].str.contains('Active')]
plt.figure(figsize=(12, 6))
sns.scatterplot(data=non_terminated_employees, x='Salary', y='ChurnRiskScore')
plt.title('Churn Risk Score vs Salary (Non-Terminated Employees)')
plt.xlabel('Salary')
plt.ylabel('Churn Risk Score')
plt.show()

# %%
high_risk_individuals[high_risk_individuals["EmploymentStatus"] == "Active_1"][['Employee_Name', 
       'Salary', 'Position', 'DOB', 'Sex',
       'HispanicLatino', 'RaceDesc', 'Department', 'ManagerName', 
       'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount', 'DaysLateLast30',
       'Absences', 'EmploymentDuration', 'ChurnRiskScore']].sort_values("ChurnRiskScore")
# Out:
#           Employee_Name  Salary                  Position       DOB Sex  \
# 64           Dee, Randy   56991   Production Technician I  04/15/88  M
# 23       Blount, Dianna   66441  Production Technician II  09/21/90   F
# 72    Dietrich, Jenna     59231        Area Sales Manager  05/14/87   F
# 69      Desimone, Carl    53189   Production Technician I  04/19/67  M
# 267  Stansfield, Norman   58273        Area Sales Manager  05/09/74  M
# 83       Erilus, Angela   56847  Production Technician II  08/25/89   F
# 91           Fett, Boba   53366          Network Engineer  06/18/87  M
#
#     HispanicLatino RaceDesc         Department     ManagerName  \
# 64              No    White  Production         Brannon Miller
# 23              No    White  Production         Michael Albert
# 72             Yes    White              Sales      John Smith
# 69              No    White  Production               Amy Dunn
# 267             No    White              Sales   Lynn Daneault
# 83              No    White  Production         Michael Albert
# 91              No    White              IT/IS    Peter Monroe
#
#       PerformanceScore  EngagementSurvey  EmpSatisfaction  \
# 64         Fully Meets              4.30                4
# 23   Needs Improvement              2.00                3
# 72                 PIP              2.30                1
# 69                 PIP              1.12                2
# 267                PIP              1.81                2
# 83                 PIP              3.00                1
# 91                 PIP              1.20                3
#
#      SpecialProjectsCount  DaysLateLast30  Absences  EmploymentDuration  \
# 64                      3               2         2                1959
# 23                      0               2         3                4612
# 72                      0               2        17                4290
# 69                      0               4         9                3422
# 267                     0               3         5                3478
# 83                      0               2         5                3422
# 91                      6               3         2                3156
#
#      ChurnRiskScore
# 64         0.388395
# 23         0.408757
# 72         0.545338
# 69         0.630192
# 267        0.684356
# 83         0.725023
# 91         0.726323

# %%
# Identifying high-risk individuals
high_risk_threshold = df['ChurnRiskScore'].quantile(0.95)
high_risk_individuals = df[df['ChurnRiskScore'] >= high_risk_threshold]

# Displaying a sample of high-risk individuals
high_risk_individuals[['Employee_Name', 'ChurnRiskScore'] + list(weights.keys())].sort_values(
    "ChurnRiskScore", ascending=False)
# Out:
#           Employee_Name  ChurnRiskScore  PerfScoreID  EmpSatisfaction  \
# 91           Fett, Boba        0.726323            1                3
# 83       Erilus, Angela        0.725023            1                1
# 267  Stansfield, Norman        0.684356            1                2
# 137   Immediato, Walter        0.675154            2                2
# 69      Desimone, Carl         0.630192            1                2
# 2     Akinkuolie, Sarah        0.567351            3                3
# 205        O'hare, Lynn        0.565700            1                2
# 112      Gonzalez, Juan        0.562704            1                3
# 72    Dietrich, Jenna          0.545338            1                1
# 132     Howard, Estelle        0.516593            3                3
# 188         Miller, Ned        0.457028            1                2
# 249       Salter, Jason        0.445845            3                3
# 307  Ybarra, Catherine         0.436212            1                2
# 94       Foreman, Tanya        0.420569            3                3
# 23       Blount, Dianna        0.408757            2                3
# 64           Dee, Randy        0.388395            1                4
#
#      EngagementSurvey  Absences  DaysLateLast30  EmploymentDuration
# 91               1.20         2               3                3156
# 83               3.00         5               2                3422
# 267              1.81         5               3                3478
# 137              2.34         4               3                 581
# 69               1.12         9               4                3422
# 2                3.02         3               0                 447
# 205              2.33         3               6                1492
# 112              3.00        10               3                 399
# 72               2.30        17               2                4290
# 132              3.24         6               0                  58
# 188              3.00         6               6                1116
# 249              4.20         2               0                 299
# 307              3.20         4               5                2583
# 94               3.66         6               0                 646
# 23               2.00         3               2                4612
# 64               4.30         2               2                1959

# %%
df[df['EmploymentStatus'].str.contains('Active')]['ChurnRiskScore']
# Out:
# 0     -0.285645
# 3     -0.477826
# 5     -0.561790
# 6      0.083793
# 7     -0.303901
#          ...
# 305    0.010609
# 306   -0.063244
# 308   -0.574812
# 309   -0.017433
# 310   -0.033587
# Name: ChurnRiskScore, Length: 207, dtype: float64

# %%
# Scatter plot to compare Churn Risk Score with Salary
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df[df['EmploymentStatus'].str.contains('Active')], x='Salary', y='ChurnRiskScore')
plt.title('Churn Risk Score vs Salary (Non-Terminated Employees)')
plt.xlabel('Salary')
plt.ylabel('Churn Risk Score')
plt.show()
